# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
np.seterr(divide = 'raise')



def compute_y(x):
    return np.arcsinh(x).flatten()



def generate_array(min_value, steps, total_number):

    array = np.linspace(min_value, min_value + steps * (total_number - 1), total_number)
    return array.reshape(1, -1)  # Reshape to 2D array with shape (1, total_number)

    # return np.linspace(min_value, min_value + steps * (total_number - 1), total_number)

def predicted_fun(x_train, phenotype, length):
    x = x_train
    prediction = eval(phenotype)
    if type(prediction)==float:
        now_pred = [prediction for i in range(length)]
        return now_pred
    return prediction
    


def plot_result(x_train_min, x_train_steps, x_train_count, actual_fun, predicted_fun, phenotype):

    X_train = generate_array(x_train_min, x_train_steps, x_train_count)
    # X_test = generate_array(x_test_min, x_test_steps, x_test_count)

    Y_train = actual_fun(X_train)
    Y_pred = predicted_fun(X_train, phenotype, len(X_train.flatten()))
    
    plt.plot(X_train.flatten(), Y_train, label="actual", color="red")
    plt.plot(X_train.flatten(), Y_pred, label="predicted", color="blue")


# plot_result(0, 1, 50,compute_y, predicted_fun, phenotype = "(-2 / ((-3 - x[0] / 3) / x[0]))")

# plot_result(0, 1, 50,compute_y, predicted_fun, phenotype = "(x[0] - (x[0] / (4 / x[0] + -4 - -5)))")

plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "x[0] / ((2.5 - ((-4.5 - x[0]) + (3.5 / 3.5))) / 5)")

# %%
# predcited using attribute grammar RUN 1 seed: 0
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "((4.5 * x[0]) / (x[0] - -4.5))")

# %%
# predcited using Normal grammar seed:0
plot_result(0, 1, 50,compute_y, predicted_fun, phenotype = "-1 * -3 - (x[0] - 3.5) / (-4.5 + -3 * x[0])")

# %%
plot_result(0, 1, 50,compute_y, predicted_fun, phenotype = "(0.5 + 5 * x[0]) / (0.5 * 3.5 + (0.5 + (x[0] / (0 + x[0] + 5)) + x[0] + 3.5))")

# %%
# predcited using attribute grammar RUN 2 seed: 1
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(5 / (x[0] + 0.1 * x[0] + 0.1 - -3.5) * x[0])")

# %%
# predcited using normal RUN 2 seed: 1
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(3 + (3 / 5))")

# %%
# predcited using attribute grammar RUN 3 seed: 2
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(3.5 / (3.5 * x[0] + 0.1) / (4 / -2) / 4.5 - -4)")

# %%
# predcited using normal RUN 2 seed: 2
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "3.5 + (-2.5 / 4 + 3.5 / 2.5) / (-3 - x[0])")

# %%
# predcited using attribute grammar RUN 4 seed: 3
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = " ((4 * x[0]) / (x[0] + 2))")

# %%
# predcited using normal RUN 4 seed: 3
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = " (4 - x[0] * 4.5 / (1.5 + x[0] * (x[0] / 1.5)))")

# %% [markdown]
# Attribute grammar with substitution x + {finalize_division_const const 1 phenotype}

# %%
# seed : 0
plot_result(0.1, 0.25, 200, compute_y, predicted_fun,
            phenotype=" (5 * x[0]) / (x[0] - -1 * 4 + 5 / 5)")

# %%
# seed : 1
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "3.5")

# %%
# seed : 2
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = " ((-1 * (x[0] - x[0])) - (x[0] * 3 - x[0]) / 0.5) / (-1 - x[0])")

# %%
# seed : 3
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(3.5 + (-4.5 / (x[0] + -2.5 + 4)))")

# %% [markdown]
# Attribution with chhosing constant with x[0] + value(by consuming codon) instead of predetermined 0.1

# %%
# seed : 0
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(-0.5 + (4 / (-2 - x[0]))) - -2.5 - -2")

# %%
# seed : 1
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "((x[0] / 3.5) + 3.5) / 3")

# %%
# seed : 2
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = "(x[0] / 2.5 - -2.5 - 3 / 2.5 / 3.5 * x[0])")

# %%
# seed : 3
plot_result(0.1, 0.25, 200,compute_y, predicted_fun, phenotype = " (4 - (3 / (x[0] + 1.5 / 1)))")
